# %% [markdown]
# # Figure 8 final plotting
#
# Interactive companion to `src/sheep_epimap/figures/fig8.py`. It generates only the code-traced panels b, d, e, f and g. Configure paths before importing the plotting module.

# %%
from pathlib import Path
import sys

repo_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(repo_root / 'src'))

from sheep_epimap.config import export_paths
export_paths(repo_root / 'config' / 'paths.local.tsv')

from sheep_epimap.figures.fig8 import (
    plot_panel_b, plot_panel_d, plot_panel_e, prepare_gwas_data,
    plot_panel_f, plot_panel_g,
)

# %% [markdown]
# ## Panel b — ChromHMM emission probabilities

# %%
plot_panel_b()

# %% [markdown]
# ## Panel d — CRE-class composition

# %%
plot_panel_d()

# %% [markdown]
# ## Panel e — phyloP raincloud

# %%
plot_panel_e()

# %% [markdown]
# ## Shared GWAS preparation for panels f and g

# %%
gwas_df, trait_info, tissue_colors = prepare_gwas_data()

# %% [markdown]
# ## Panel f — CRE-class hit overlap

# %%
plot_panel_f(gwas_df)

# %% [markdown]
# ## Panel g — sfCRE trait enrichment

# %%
plot_panel_g(gwas_df, trait_info, tissue_colors)
